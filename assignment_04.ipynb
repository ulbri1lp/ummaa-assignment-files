# %%
import csv

#Importing our modules

# %%
# Line count

with open('ummaa_ethnographic.csv', encoding='utf-8') as f:
    data = csv.reader(f, delimiter=',')
    line_count = 0
    for row in data:
        line_count += 1 
    print(f'\nRead {line_count} lines.')
# Out:
# Read 755 lines.

# %%
# Merging accession number and original number, object type and type, and description and curator notes columns

with open('ummaa_ethnographic.csv', encoding='utf-8') as f:
    reader = csv.reader(f)
    with open('temp.csv', 'w', newline="") as g:
        writer = csv.writer(g)
        for row in reader:
            if row[7] != "":
                if row[14] != "":
                    if row[8] != "":
                        new_row =  row[:2] + ['; '.join([row[2], row[7]])] + row[3:6] + ['; '.join([row[6], row[8]])] + row[9:14] + ['; '.join([row[14], row[15]])]
                    else:
                        new_row =  row[:2] + ['; '.join([row[2], row[7]])] + row[3:6] + [''.join([row[6], row[8]])] + row[9:14] + ['; '.join([row[14], row[15]])]
                else:
                    if row[8] != "":
                        new_row =  row[:2] + ['; '.join([row[2], row[7]])] + row[3:6] + ['; '.join([row[6], row[8]])] + row[9:14] + [''.join([row[14], row[15]])]
                    else:
                        new_row =  row[:2] + ['; '.join([row[2], row[7]])] + row[3:6] + [''.join([row[6], row[8]])] + row[9:14] + [''.join([row[14], row[15]])]
            else:
                if row[14] != "":
                    if row[8] != "":
                        new_row =  row[:2] + [''.join([row[2], row[7]])] + row[3:6] + ['; '.join([row[6], row[8]])] + row[9:14] + ['; '.join([row[14], row[15]])]
                    else:
                        new_row =  row[:2] + [''.join([row[2], row[7]])] + row[3:6] + [''.join([row[6], row[8]])] + row[9:14] + ['; '.join([row[14], row[15]])]
                else:
                    if row[8] != "":
                        new_row =  row[:2] + [''.join([row[2], row[7]])] + row[3:6] + ['; '.join([row[6], row[8]])] + row[9:14] + [''.join([row[14], row[15]])]
                    else:
                        new_row =  row[:2] + [''.join([row[2], row[7]])] + row[3:6] + [''.join([row[6], row[8]])] + row[9:14] + [''.join([row[14], row[15]])]
            writer.writerow(new_row)

# %%
# renaming headers 

inputFileName = "temp.csv"
outputFileName = "output.csv"

with open(inputFileName, 'r', encoding="utf-8") as inFile, open(outputFileName, 'w', newline="") as outfile:
    r = csv.reader(inFile)
    w = csv.writer(outfile)

    next(r, None)  # skip the first row from the reader, the old header
    # write new header
    w.writerow(['identifier', 'audience', 'alternateIdentifier', 'provenance', 'dateAccepted', 'extent', 'type', 'medium', 'date', 'subject/geographic', 'originInfo/place', 'culture', 'description'])

    # copy the rest
    for row in r:
        w.writerow(row)
